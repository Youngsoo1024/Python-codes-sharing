# %%
URL = "https://www.korswim.co.kr/page/14"
URL_GR = "https://graphenesq.co.kr"

import gazpacho
html = gazpacho.get(URL)
len(html)

# %%
html

# %%
fav = "Life, the Universe and Everything.."

fav[-13:]

# %%
html [133:150]
# Out:
# ' content="신기록현황 |'

# %%
from_where = html.find("<table")
html[from_where:from_where+500]
# Out:
# '<table>\n\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<th class="s14-th s14-th1">종목</th>\n\t\t\t\t\t\t\t<th class="s14-th s14-th2">세계 <br>신기록</th>\n\t\t\t\t\t\t\t<th class="s14-th s14-th3">올림픽 <br>신기록</th>\n\t\t\t\t\t\t\t<th class="s14-th s14-th4">아시아 <br>신기록</th>\n\t\t\t\t\t\t\t<th class="s14-th s14-th5">한국 <br>신기록</th>\n\t\t\t\t\t\t</tr>\n\t\t\t\t\t\t\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<td class="s14-td s14-td1">50m</td>\n\t\t\t\t\t\t\t<td class="s14-td s14-td-tbx s14-td2">\n\t\t\t\t\t\t\t\t<h3 class="s14-t-h3">00:20.91</h3>\n\t\t\t\t\t\t\t\t<h4 class="s14-t-h4">Cesar CIELO <span>(BRA)</span></h4>\n\t\t\t\t\t\t\t\t<p '

# %%
soup = gazpacho.Soup(html)
type(soup)
# Out:
# gazpacho.soup.Soup

# %%
print(dir(soup))
# Out:
# ['attrs', 'find', 'get', 'html', 'strip', 'tag', 'text']

# %%
tables = soup.find("table")

# %%
type(tables)
# Out:
# list

# %%
type(tables[0])
# Out:
# gazpacho.soup.Soup
