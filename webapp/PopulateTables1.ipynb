# %%
fn = 'Abi-10-100m-Back.txt'
name, age, distance, stroke = fn.removesuffix(".txt").split("-")

# %%
name, age
# Out:
# ('Abi', '10')

# %%
distance, stroke
# Out:
# ('100m', 'Back')

# %%
import os

FOLDER = "swimdata/"

files = os.listdir(FOLDER)

# %%
first = files[0]
print(first)
name, age, _, _ = first.removesuffix(".txt").split("-")
name, age
# Out:
# Hannah-13-100m-Free.txt
# ('Hannah', '13')

# %%
# Don't be tempted to do this (i.e., don't use an f-string here).

SQL = f"""
    insert into swimmers
    (name, age)
    values
    ("{name}", {age})
"""
print(SQL)
# Out:
#     insert into swimmers
#     (name, age)
#     values
#     ("Hannah", 13)

# %%
import DBcm

db_details = "CoachDB.sqlite3"

# %%
# Do this instead... use SQL Injection Attack safeguards with placeholders.

SQL_INSERT = """
    insert into swimmers
    (name, age)
    values
    (?, ?)
"""
print(SQL_INSERT)
# Out:
#     insert into swimmers
#     (name, age)
#     values
#     (?, ?)

# %%
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL_INSERT, (name, age,))

# %%
SQL = """select * from swimmers"""
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL)
    results = db.fetchall()
results
# Out:
# [(288, 'Hannah', 13),
#  (289, 'Darius', 13),
#  (290, 'Owen', 15),
#  (291, 'Mike', 15),
#  (292, 'Abi', 10),
#  (293, 'Ruth', 13),
#  (294, 'Tasmin', 15),
#  (295, 'Erika', 15),
#  (296, 'Maria', 9),
#  (297, 'Elba', 14),
#  (298, 'Ali', 12),
#  (299, 'Chris', 17),
#  (300, 'Aurora', 13),
#  (301, 'Katie', 9),
#  (302, 'Alison', 14),
#  (303, 'Emma', 13),
#  (304, 'Calvin', 9),
#  (305, 'Blake', 15),
#  (306, 'Bill', 18),
#  (307, 'Dave', 17),
#  (308, 'Lizzie', 14),
#  (309, 'Carl', 15),
#  (310, 'Hannah', 13)]

# %%
SQL = """delete from swimmers"""
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL)

# %%
SQL = """select * from swimmers"""
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL)
    results = db.fetchall()
results
# Out:
# []

# %%
SQL = """delete from swimmers"""
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL)

# %%
# for fn in files:
#     name, age, _, _ = fn.removesuffix(".txt").split("-")
#     with DBcm.UseDatabase(db_details) as db:
#         db.execute(SQL_INSERT, (name, age, ))

# %%
import os

import DBcm

db_details = "CoachDB.sqlite3"

FOLDER = "swimdata/"

files = os.listdir(FOLDER)


SQL_INSERT = """
    insert into swimmers
    (name, age)
    values
    (?, ?)
"""

with DBcm.UseDatabase(db_details) as db:
    for fn in files:
        name, age, _, _ = fn.removesuffix(".txt").split("-")    
        db.execute(SQL_INSERT, (name, age, ))

# %%
SQL = """delete from swimmers"""
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL)

# %%
import os

import DBcm

db_details = "CoachDB.sqlite3"

FOLDER = "swimdata/"

files = os.listdir(FOLDER)


SQL_SELECT = """
    select * from swimmers
    where name = ? and age = ?
"""

SQL_INSERT = """
    insert into swimmers
    (name, age)
    values
    (?, ?)
"""

with DBcm.UseDatabase(db_details) as db:
    for fn in files:
        name, age, _, _ = fn.removesuffix(".txt").split("-")
        db.execute(SQL_SELECT, (name, age,))
        if db.fetchall():
            continue
        db.execute(SQL_INSERT, (name, age,))

# %%
import os

import DBcm

db_details = "CoachDB.sqlite3"

FOLDER = "swimdata/"

files = os.listdir(FOLDER)


SQL_SELECT = """
    select * from events
    where distance = ? and stroke = ?
"""

SQL_INSERT = """
    insert into events
    (distance, stroke)
    values
    (?, ?)
"""

with DBcm.UseDatabase(db_details) as db:
    for fn in files:
        _, _, distance, stroke = fn.removesuffix(".txt").split("-")
        db.execute(SQL_SELECT, (distance, stroke,))
        if db.fetchall():
            continue
        db.execute(SQL_INSERT, (distance, stroke,))

# %%
import os

FOLDER = "swimdata/"

files = os.listdir(FOLDER)

# %%
import DBcm

db_details = "CoachDB.sqlite3"

# %%
SQL = """select * from swimmers"""
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL)
    results = db.fetchall()
results
# Out:
# [(371, 'Hannah', 13),
#  (372, 'Darius', 13),
#  (373, 'Owen', 15),
#  (374, 'Mike', 15),
#  (375, 'Abi', 10),
#  (376, 'Ruth', 13),
#  (377, 'Tasmin', 15),
#  (378, 'Erika', 15),
#  (379, 'Maria', 9),
#  (380, 'Elba', 14),
#  (381, 'Ali', 12),
#  (382, 'Chris', 17),
#  (383, 'Aurora', 13),
#  (384, 'Katie', 9),
#  (385, 'Alison', 14),
#  (386, 'Emma', 13),
#  (387, 'Calvin', 9),
#  (388, 'Blake', 15),
#  (389, 'Bill', 18),
#  (390, 'Dave', 17),
#  (391, 'Lizzie', 14),
#  (392, 'Carl', 15)]

# %%
SQL = """select * from events"""
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL)
    results = db.fetchall()
results
# Out:
# [(14, '100m', 'Free'),
#  (15, '100m', 'Back'),
#  (16, '100m', 'Fly'),
#  (17, '50m', 'Back'),
#  (18, '200m', 'Free'),
#  (19, '200m', 'Back'),
#  (20, '50m', 'Free'),
#  (21, '50m', 'Breast'),
#  (22, '200m', 'IM'),
#  (23, '100m', 'Breast'),
#  (24, '400m', 'Free'),
#  (25, '50m', 'Fly'),
#  (26, '200m', 'Breast')]

# %%
with DBcm.UseDatabase(db_details) as db:
    db.execute("pragma table_info(times)")
    results = db.fetchall()
print(results)
# Out:
# [(0, 'swimmer_id', 'INTEGER', 1, None, 0), (1, 'event_id', 'INTEGER', 1, None, 0), (2, 'time', 'varchar(16)', 1, None, 0), (3, 'ts', 'timestamp', 0, 'current_timestamp', 0)]

# %%
SQL_GET_SWIMMER = """
    select id from swimmers
    where name = ? and age = ?
"""

# %%
SQL_GET_EVENT = """
    select id from events
    where distance = ? and stroke = ?
"""

# %%
SQL_INSERT_TIMES = """
    insert into times
    (swimmer_id, event_id, time)
    values
    (?, ?, ?)
"""

# %%
SQL = """select * from times"""
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL)
    results = db.fetchall()
results
# Out:
# [(288, 14, '1:21.43', '2023-05-15 19:33:12'),
#  (288, 14, '1:21.40', '2023-05-15 19:33:12'),
#  (288, 14, '1:21.62', '2023-05-15 19:33:12'),
#  (288, 14, '1:25.38', '2023-05-15 19:33:12'),
#  (289, 15, '1:22.57', '2023-05-15 19:33:12'),
#  (289, 15, '1:29.64', '2023-05-15 19:33:12'),
#  (289, 15, '1:20.39', '2023-05-15 19:33:12'),
#  (289, 15, '1:23.83', '2023-05-15 19:33:12'),
#  (290, 14, '1:15.57', '2023-05-15 19:33:12'),
#  (290, 14, '1:14.40', '2023-05-15 19:33:12'),
#  (290, 14, '1:19.82', '2023-05-15 19:33:12'),
#  (290, 14, '1:12.90', '2023-05-15 19:33:12'),
#  (291, 14, '1:02.52', '2023-05-15 19:33:12'),
#  (291, 14, '1:02.56', '2023-05-15 19:33:12'),
#  (291, 14, '1:06.41', '2023-05-15 19:33:12'),
#  (291, 14, '1:07.08', '2023-05-15 19:33:12'),
#  (291, 14, '1:02.56', '2023-05-15 19:33:12'),
#  (291, 14, '1:03.23', '2023-05-15 19:33:12'),
#  (291, 14, '1:04.54', '2023-05-15 19:33:12'),
#  (288, 15, '1:35.75', '2023-05-15 19:33:12'),
#  (301, 14, '1:20.81', '2023-05-15 19:33:12'),
#  (301, 14, '1:23.61', '2023-05-15 19:33:12'),
#  (301, 14, '1:24.80', '2023-05-15 19:33:12'),
#  (301, 14, '1:22.05', '2023-05-15 19:33:12'),
#  (301, 14, '1:22.58', '2023-05-15 19:33:12'),
#  (301, 14, '1:23.94', '2023-05-15 19:33:12'),
#  (305, 16, '1:11.49', '2023-05-15 19:33:12'),
#  (305, 16, '1:10.16', '2023-05-15 19:33:12'),
#  (305, 16, '1:12.59', '2023-05-15 19:33:12'),
#  (305, 16, '1:11.63', '2023-05-15 19:33:12'),
#  (305, 16, '1:09.43', '2023-05-15 19:33:12'),
#  (295, 23, '1:36.72', '2023-05-15 19:33:12'),
#  (295, 23, '1:34.78', '2023-05-15 19:33:12'),
#  (295, 23, '1:34.05', '2023-05-15 19:33:12'),
#  (295, 23, '1:32.78', '2023-05-15 19:33:12'),
#  (295, 23, '1:33.51', '2023-05-15 19:33:12'),
#  (295, 23, '1:33.29', '2023-05-15 19:33:12'),
#  (295, 23, '1:36.47', '2023-05-15 19:33:12'),
#  (295, 23, '1:31.82', '2023-05-15 19:33:12'),
#  (301, 15, '1:33.36', '2023-05-15 19:33:12'),
#  (301, 15, '1:31.52', '2023-05-15 19:33:12'),
#  (301, 15, '1:28.10', '2023-05-15 19:33:12'),
#  (301, 15, '1:33.37', '2023-05-15 19:33:12'),
#  (301, 15, '1:32.89', '2023-05-15 19:33:12'),
#  (301, 15, '1:33.38', '2023-05-15 19:33:12'),
#  (301, 15, '1:32.03', '2023-05-15 19:33:12'),
#  (301, 15, '1:32.71', '2023-05-15 19:33:12')]

# %%
SQL = """delete from times"""
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL)

# %%
with DBcm.UseDatabase(db_details) as db:
    for fn in files:
        name, age, distance, stroke = fn.removesuffix(".txt").split("-")
        db.execute(SQL_GET_SWIMMER, (name, age,))
        s_id = db.fetchone()[0]
        db.execute(SQL_GET_EVENT, (distance, stroke,))
        e_id = db.fetchone()[0]
        with open(FOLDER+fn) as sf:
            times = sf.read().strip().split(",")
            for t in times:
                db.execute(SQL_INSERT_TIMES, (s_id, e_id, t,))

# %%
SQL = """select count(*) from times"""
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL)
    results = db.fetchone()[0]
results
# Out:
# 338

# %%
SQL = """select * from times limit 10"""
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL)
    results = db.fetchall()
results
# Out:
# [(371, 14, '1:21.43', '2025-12-16 21:04:03'),
#  (371, 14, '1:21.40', '2025-12-16 21:04:03'),
#  (371, 14, '1:21.62', '2025-12-16 21:04:03'),
#  (371, 14, '1:25.38', '2025-12-16 21:04:03'),
#  (372, 15, '1:22.57', '2025-12-16 21:04:03'),
#  (372, 15, '1:29.64', '2025-12-16 21:04:03'),
#  (372, 15, '1:20.39', '2025-12-16 21:04:03'),
#  (372, 15, '1:23.83', '2025-12-16 21:04:03'),
#  (373, 14, '1:15.57', '2025-12-16 21:04:03'),
#  (373, 14, '1:14.40', '2025-12-16 21:04:03')]
