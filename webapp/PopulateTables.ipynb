# %%
fn = "Abi-10-100m-Back.txt"
name, age, distance, stroke = fn.removesuffix(".txt").split("-")

# %%
name, age
# Out:
# ('Abi', '10')

# %%
import os

FOLDER = "swimdata"

files = os.listdir(FOLDER)

# %%
first = files[0]
print(first)
name, age, _, _ = first.removesuffix(".txt").split("-")
name, age
# Out:
# Hannah-13-100m-Free.txt
# ('Hannah', '13')

# %%
import os
from DBcm import UseDatabase

db_details = "CoachDB.sqlite3"
FOLDER = "swimdata"

files = os.listdir(FOLDER)

SQL_SELECT= """
    select * from swimmers
    where name = ? and age = ?
"""

SQL_INSERT = """
    insert into swimmers
    (name, age)
    values
    (?, ?)
"""

with UseDatabase(db_details) as db:
    for fn in files:
        name, age, _, _ = fn.removesuffix(".txt").split("-")
        db.execute(SQL_SELECT, (name, age,))
        if db.fetchall():
            continue
        db.execute(SQL_INSERT, (name, age,))

# %%
SQL = """delete from swimmers"""
with UseDatabase(db_details) as db:
    db.execute(SQL)
    results = db.fetchall()
results
# Out:
# []

# %%
SQL = """select * from swimmers"""
with UseDatabase(db_details) as db:
    db.execute(SQL)
    results = db.fetchall()
results
# Out:
# []

# %%
import os
from DBcm import UseDatabase

db_details = "CoachDB.sqlite3"
FOLDER = "swimdata"

files = os.listdir(FOLDER)

SQL_SELECT= """
    select * from events
    where distance = ? and stroke = ?
"""

SQL_INSERT = """
    insert into events
    (distance, stroke)
    values
    (?, ?)
"""

with UseDatabase(db_details) as db:
    for fn in files:
        _, _, distance, stroke = fn.removesuffix(".txt").split("-")
        db.execute(SQL_SELECT, (distance, stroke,))
        if db.fetchall():
            continue
        db.execute(SQL_INSERT, (distance, stroke,))

# %%
SQL = """select * from events"""
with UseDatabase(db_details) as db:
    db.execute(SQL)
    results = db.fetchall()
results
# Out:
# [(1, '100m', 'Free'),
#  (2, '100m', 'Back'),
#  (3, '100m', 'Fly'),
#  (4, '50m', 'Back'),
#  (5, '200m', 'Free'),
#  (6, '200m', 'Back'),
#  (7, '50m', 'Free'),
#  (8, '50m', 'Breast'),
#  (9, '200m', 'IM'),
#  (10, '100m', 'Breast'),
#  (11, '400m', 'Free'),
#  (12, '50m', 'Fly'),
#  (13, '200m', 'Breast')]

# %%
with UseDatabase(db_details) as db:
    db.execute("pragma table_info(times)")
    results = db.fetchall()
results
# Out:
# [(0, 'swimmer_id', 'INTEGER', 1, None, 1),
#  (1, 'event_id', 'INTEGER', 1, None, 0),
#  (2, 'time', 'varchar(16)', 1, None, 0),
#  (3, 'ts', 'timestamp', 0, 'current_timestamp', 0)]

# %%
SQL = """select * from times"""
with UseDatabase(db_details) as db:
    db.execute(SQL)
    results = db.fetchall()
results
# Out:
# [(937, 1, '1:21.43', '2025-12-16 19:29:26'),
#  (981, 1, '1:21.43', '2025-12-16 19:42:18'),
#  (1041, 1, '1:21.43', '2025-12-16 19:42:29')]

# %%
# Out:
#   Cell In[61], line 1
#     PRAGMA table_info(times)
#            ^
# SyntaxError: invalid syntax

# %%
SQL = """delete from times"""
with UseDatabase(db_details) as db:
    db.execute(SQL)

# %%
import os
from DBcm import UseDatabase

db_details = "CoachDB.sqlite3"

FOLDER = "swimdata/"

files = os.listdir(FOLDER)

SQL_GET_SWIMMER = """
    select id from swimmers
    where name = ? and age = ?
"""

SQL_GET_EVENT = """
    select id from events
    where distance = ? and stroke = ?
"""
SQL_INSERT = """
    insert into times
    (swimmer_id, event_id, time)
    values
    (?, ?, ?)
"""

with UseDatabase(db_details) as db:
    for fn in files:
        name, age, distance, stroke = fn.removesuffix(".txt").split("-")
        db.execute(SQL_GET_SWIMMER, (name, age,))
        s_id = db.fetchone()[0]
        db.execute(SQL_GET_EVENT, (distance, stroke,))
        e_id = db.fetchone()[0]
        with open(FOLDER+fn) as sf:
            times = sf.read().strip().split(",")
            for t in times:
                db.execute(SQL_INSERT, (s_id, e_id, t,))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 30
#      29 db.execute(SQL_GET_SWIMMER, (name, age,))
# ---> 30 s_id = db.fetchone()[0]
#      31 db.execute(SQL_GET_EVENT, (distance, stroke,))
#
# TypeError: 'NoneType' object is not subscriptable
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 26
#      15 SQL_GET_EVENT = """
#      16     select id from events
#      17     where distance = ? and stroke = ?
#      18 """
#      19 SQL_INSERT = """
#      20     insert into times
#      21     (swimmer_id, event_id, time)
#      22     values
#      23     (?, ?, ?)
#      24 """
# ---> 26 with UseDatabase(db_details) as db:
#      27     for fn in files:
#      28         name, age, distance, stroke = fn.removesuffix(".txt").split("-")
#
# File ~/Documents/GitHub/Python-codes-sharing/webapp/.venv/lib/python3.13/site-packages/DBcm.py:118, in UseDatabase.__exit__(self, exc_type, exc_value, exc_traceback)
#     116     raise SQLError(exc_value)
#     117 elif exc_type:
# --> 118     raise exc_type(exc_value)
#
# TypeError: 'NoneType' object is not subscriptable
