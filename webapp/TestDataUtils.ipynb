# %%
import data_utils

# %%
print([x for x in dir(data_utils) if not x.startswith("__")])
# Out:
# ['DBcm', 'SQL_CHART_DATA_BY_SWIMMER_EVENT_SESSION', 'SQL_SESSIONS', 'SQL_SWIMMERS_BY_SESSION', 'SQL_SWIMMERS_EVENTS_BY_SESSION', 'db_details', 'get_session_swimmers', 'get_swim_sessions', 'get_swimmers_events', 'get_swimmers_times']

# %%
help(data_utils.get_swim_sessions)
# Out:
# Help on function get_swim_sessions in module data_utils:
#
# get_swim_sessions()
#     Return a tuple-list of unique session timestamps.

# %%
data_utils.get_swim_sessions()
# Out:
# [('2025-12-16 21:04:03',),
#  ('2025-12-17 14:20:39',),
#  ('2025-12-17 14:26:33',),
#  ('2025-12-17 14:29:06',),
#  ('2025-12-17 14:29:13',)]

# %%
data_utils.get_session_swimmers("2025-12-17")
# Out:
# [('Abi', 10),
#  ('Ali', 12),
#  ('Alison', 14),
#  ('Aurora', 13),
#  ('Bill', 18),
#  ('Blake', 15),
#  ('Calvin', 9),
#  ('Carl', 15),
#  ('Chris', 17),
#  ('Darius', 13),
#  ('Darius', 8),
#  ('Dave', 17),
#  ('Elba', 14),
#  ('Emma', 13),
#  ('Erika', 15),
#  ('Hannah', 13),
#  ('Katie', 9),
#  ('Lizzie', 14),
#  ('Maria', 9),
#  ('Mike', 15),
#  ('Owen', 15),
#  ('Ruth', 13),
#  ('Tasmin', 15)]

# %%
data_utils.get_swimmers_events("Darius", 8,"2025-12-17")
# Out:
# [('50m', 'Breast'), ('50m', 'Free'), ('50m', 'Back')]

# %%
data_utils.get_swimmers_times("Darius", 8, "50m", "Free", "2025-12-17")
# Out:
# [('39.42',),
#  ('36.13',),
#  ('37.66',),
#  ('39.07',),
#  ('39.42',),
#  ('36.13',),
#  ('37.66',),
#  ('39.07',)]
